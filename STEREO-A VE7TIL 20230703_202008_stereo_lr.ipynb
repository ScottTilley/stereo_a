# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from construct import *

import sys
sys.path.append('/home/scott/Dropbox/satobs/STEREO_A/')
import ccsds

import collections
import datetime
import struct

plt.rcParams['figure.figsize'] = (14, 7)
plt.rcParams['figure.facecolor'] = 'w'

# %%
def process_frames(input_file, output_file):
    frame_length = 8952
    new_frame_length = 8920
    bits_to_remove = 32

    with open(input_file, 'rb') as f_in, open(output_file, 'wb') as f_out:
        while True:
            frame = f_in.read(frame_length // 8)  # Read frame in bytes
            if not frame:  # Reached end of file
                break
            new_frame = frame[bits_to_remove // 8:]  # Remove first 32 bits
            f_out.write(new_frame)

    print(f"Processed {input_file}. New file saved as {output_file}.")

#satdump .cadu filename
input_filename = '/media/scott/fast/img/20230703a/20230703_202008_stereo_lr.cadu'

#stripped output file compatible with the script below
output_filename = 'output_frames.bin'
process_frames(input_filename, output_filename)
# Out:
# Processed /media/scott/fast/img/20230703a/20230703_202008_stereo_lr.cadu. New file saved as output_frames.bin.

# %%
def load_frames(file):
    frame_size = 223 * 5
    frames = np.fromfile(file, dtype = 'uint8')
    return frames[:frames.size//frame_size*frame_size].reshape(-1, frame_size)

#frames = load_frames('stereo-a_bg2bhc_frames_20220924_0710.raw')
#frames = load_frames('stereo-a_bg2bhc_frames_20220924_1035.raw')
frames = load_frames('output_frames.bin')

# %%
# Filename extensions 

# .711 COR2
# .725 hi_1
# .734 hi_2
# .743 EUV

# %%
import numpy as np

def print_ascii_sequences(frames):
    ascii_sequence = ""
    for byte in np.nditer(frames):
        if 32 <= byte <= 126:
            ascii_sequence += chr(byte)
        else:
            if len(ascii_sequence) > 11:
                print(ascii_sequence)
            ascii_sequence = ""
    if len(ascii_sequence) > 1:
        print(ascii_sequence)



#print ASCII strings greater than 11 chars long, these tend to be filenames.
print_ascii_sequences(frames)
# Out:
# N7032402.725
# kN703040Q.743
# kN703040Q.743
# kN703041T.743
# kN703041T.743
# kN7030432.743
# kN7030435.743
# kN7030435.743
# N703243E.734
# AKS]S][g]geseiioummk
# N703243E.734
# kN7030443.743
# EfFiFA?H?"Bt;
# kN7030443.743
# kN703044T.743
# kN703044T.743
# N7030455.711
# N7030455.711
# N7030459.711
# N7030459.711
# N703045D.711
# N703045D.711
# kN7030460.743
# kN7030463.743
# kN7030463.743
# kN7030479.743
# kN7030479.743
# kN703048F.743
# kN703048F.743
# _D"C1EhFyF.@O?
# C=EnFzF*@M?zBp<(?
# kN703049H.743
# kN703049H.743
# kN703049J.743
# kN703049J.743
# kN70304AN.743
# kN70304AN.743
# kN70304BU.743
# kN70304BU.743
# N70304CC.711
# N70304CC.711
# N70304CG.711
# EoFsF(@<?jB`<
# N70304CK.711
# N70304CK.711
# kN70304D7.743
# CWCVEcFoF_>n>
# kN70304D7.743
# kN70304DA.743
# kN70304DA.743
# N70324DL.725
# >Iu1F#Tpx%sN5<
# N70324DL.725
# kN70304E9.743
# kN70304E9.743
# F#A=@HBP>"@g?J
# kN70304FC.743

# %% [markdown]
# ## TM Primary Headers
#
# The frames are TM Space Data Link frames. The spacecraft ID is 234 (0xEA). Virtual channels 0 and 7 are in use. OCF and secondary headers are used.

# %%
TMPrimaryHeader = BitStruct(
    'transfer_frame_version_number' / BitsInteger(2),
    'spacecraft_id' / BitsInteger(10),
    'virtual_channel_id' / BitsInteger(3),
    'ocf_flag' / Flag,
    'master_channel_frame_count' / BitsInteger(8),
    'virtual_channel_frame_count' / BitsInteger(8),
    'secondary_header_flag' / Flag,
    'synch_flag' / Flag,
    'packet_order_flag' / Flag,
    'segment_length_id' / BitsInteger(2),
    'first_header_pointer' / BitsInteger(11)
)

TransferFrameSecondaryHeaderId = BitStruct(
    'version_number' / BitsInteger(2),
    'header_length' / BitsInteger(6)
)

CLCW = BitStruct(
    'control_word_type' / Flag,
    'clcw_version_number' / BitsInteger(2),
    'status_field' / BitsInteger(3),
    'cop_in_effect' / BitsInteger(2),
    'virtual_channel_identification' / BitsInteger(6),
    'rsvd_spare' / BitsInteger(2),
    'no_rf_avail' / Flag,
    'no_bit_lock' / Flag,
    'lock_out' / Flag,
    'wait' / Flag,
    'retransmit' / Flag,
    'farm_b_counter' / BitsInteger(2),
    'rsvd_spare2' / BitsInteger(1),
    'report_value' / BitsInteger(8)
)

# %%
tm = [TMPrimaryHeader.parse(f) for f in frames]
scid = np.array([h.spacecraft_id for h in tm])
vcid = np.array([h.virtual_channel_id for h in tm])
v_framecount = np.array([h.virtual_channel_frame_count for h in tm])
m_framecount = np.array([h.master_channel_frame_count for h in tm])

# %%
tm[:5]
# Out:
# [Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=7, ocf_flag=True, master_channel_frame_count=222, virtual_channel_frame_count=128, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=0),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=7, ocf_flag=True, master_channel_frame_count=223, virtual_channel_frame_count=129, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=0),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=7, ocf_flag=True, master_channel_frame_count=224, virtual_channel_frame_count=130, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=0),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=7, ocf_flag=True, master_channel_frame_count=225, virtual_channel_frame_count=131, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=0),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=7, ocf_flag=True, master_channel_frame_count=226, virtual_channel_frame_count=132, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=0)]

# %%
collections.Counter(scid)
# Out:
# Counter({234: 563})

# %%
collections.Counter(vcid)
# Out:
# Counter({7: 546, 0: 17})

# %%
plt.plot(np.diff(m_framecount) - 1, '.-')
plt.title('Frame loss (using master channel frame counter)')
plt.ylabel('Frame loss')
plt.xlabel('Frame number');

# %% [markdown]
# ## TM Secondary Header
#
# The TM Secondary Header contains a timestamp giving the seconds since 2006-10-25 12:00 UTC as a 32-bit integer, plus an additional 8-bit integer that counts 1/256-ths of a second. The remaining 9 bytes of the header are filled with `0x00` in the virtual channel 7 frames and with `0xff` in the virtual channel 0 frames.

# %%
sec_header_id = [TransferFrameSecondaryHeaderId.parse(f[TMPrimaryHeader.sizeof():])
                 for f in frames]
all([sec_header_id[0] == h for h in sec_header_id])
# Out:
# True

# %%
sec_header_id[0]
# Out:
# Container(version_number=0, header_length=14)

# %%
plt.figure(figsize=(6, 6))
plt.imshow(frames[:, 6:6+15], interpolation='none', aspect='auto')
plt.title('TM Secondary Header bytes');

# %%
np.all(frames[vcid != 0, 12:6+15] == 0)
# Out:
# True

# %%
np.all(frames[vcid == 0, 12:6+15] == 0xff)
# Out:
# True

# %%
#timestamps_secs = (
   # frames[:, 7:11].view('uint32').byteswap().ravel().astype('float')+ frames[:, 11].astype('float') / 256)
    
timestamps_secs = (frames[:, 7:11].copy().view('uint32').byteswap().ravel().astype('float')+ frames[:, 11].astype('float') / 256)

# %%
np.diff(timestamps_secs)
# Out:
# array([14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 84.859375  , 14.14453125, 14.140625  ,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 56.5703125 ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.140625  , 14.14453125, 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.140625  ,
#        14.14453125, 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.140625  , 14.14453125, 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.140625  , 14.14453125, 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  , 14.14453125, 14.140625  , 14.14453125,
#        14.14453125, 14.140625  ])

# %%
(5*223*8 + 4 + 32) * 6 / 3.8e3
# Out:
# 14.141052631578948

# %%
1/256
# Out:
# 0.00390625

# %%
datetime.datetime(2022, 9, 24, 10, 35, 0) - datetime.timedelta(seconds=timestamps_secs[0])
# Out:
# datetime.datetime(2006, 1, 16, 0, 50, 1, 816406)

# %%
epoch = np.datetime64('2006-10-25T12:00:00')

# %%
timestamps = epoch + np.timedelta64(1, 'ns') * (timestamps_secs * 1e9)

# %%
timestamps[0]
# Out:
# numpy.datetime64('2023-07-03T21:44:58.183593728')

# %%
plt.plot(m_framecount, timestamps, '.-')
plt.title('Secondary header timestamps vs. master channel frame count')
plt.xlabel('Master channel frame count')
plt.ylabel('Timestamp');

# %% [markdown]
# ## Operational Control Field
#
# The operational control field shows receiver lock, event though the frequency of the downlink transmitter changes during the recording (indicating loss of ground lock).

# %%
ocf = frames[:, -6:-2]
np.all(ocf == ocf[0])
# Out:
# True

# %%
print(CLCW.parse(ocf[0]))
# Out:
# Container:
#     control_word_type = False
#     clcw_version_number = 0
#     status_field = 0
#     cop_in_effect = 1
#     virtual_channel_identification = 2
#     rsvd_spare = 0
#     no_rf_avail = False
#     no_bit_lock = False
#     lock_out = False
#     wait = False
#     retransmit = False
#     farm_b_counter = 3
#     rsvd_spare2 = 0
#     report_value = 23

# %% [markdown]
# ## Virtual channel 0
#
# Frames in virtual channel 0 carry OID (only idle data). The transfer frame data field is filled with `0xff` bytes.

# %%
[h for h in tm if h.virtual_channel_id == 0]
# Out:
# [Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=16, virtual_channel_frame_count=218, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=17, virtual_channel_frame_count=219, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=21, virtual_channel_frame_count=220, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=25, virtual_channel_frame_count=221, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=33, virtual_channel_frame_count=222, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=246, virtual_channel_frame_count=224, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=19, virtual_channel_frame_count=225, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=20, virtual_channel_frame_count=226, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=24, virtual_channel_frame_count=227, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=75, virtual_channel_frame_count=228, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=96, virtual_channel_frame_count=229, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=109, virtual_channel_frame_count=230, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=113, virtual_channel_frame_count=231, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=10, virtual_channel_frame_count=232, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=14, virtual_channel_frame_count=233, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=18, virtual_channel_frame_count=234, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046),
#  Container(transfer_frame_version_number=0, spacecraft_id=234, virtual_channel_id=0, ocf_flag=True, master_channel_frame_count=22, virtual_channel_frame_count=235, secondary_header_flag=True, synch_flag=False, packet_order_flag=False, segment_length_id=3, first_header_pointer=2046)]

# %%
np.all(frames[vcid == 0][:, 12:-6] == 0xff)
# Out:
# True

# %% [markdown]
# ## Virtual channel 7
#
# Frames in virtual channel 7 contain 4 Space Packets with a length of 272 bytes (which divides the transfer frame data field evenly in 4). The Space Packets in the non-idle APIDs have a Secondary Header with a 32-bit timestamp giving the number of seconds since the CCSDS time code epoch 1958-01-01 00:00:00 TAI.

# %%
plt.figure(figsize=(8, 8))
plt.imshow(frames[vcid == 7, 6+15:-6], interpolation='none', aspect='auto')
plt.title('STEREO-A virtual channel 7 transfer frame data field');

# %%
# 265 bytes = Space Packet data length field (indicates length-1)
# 6 bytes = Space Packet primary header
# 4 Space Packets per TM frame
# 6 bytes = TM Primary Header
# 15 bytes = TM Secondary Header
# 4 bytes = OCF (CLCW)
# 2 bytes = FECF (CRC-16)
(265 + 1 + 6) * 4 + 6 + 15 + 4 + 2 == frames.shape[1]
# Out:
# True

# %%
packet_len = 265 + 1 + 6

# %%
packet_headers = [ccsds.SpacePacketPrimaryHeader.parse(f[6+15+k*packet_len:])
                  for f in frames[vcid == 7] for k in range(4)]

# %%
packet_headers[:5]
# Out:
# [Container(ccsds_version=0, packet_type=0, secondary_header_flag=True, APID=1393, sequence_flags=3, packet_sequence_count_or_name=1, data_length=265),
#  Container(ccsds_version=0, packet_type=0, secondary_header_flag=True, APID=624, sequence_flags=3, packet_sequence_count_or_name=3273, data_length=265),
#  Container(ccsds_version=0, packet_type=0, secondary_header_flag=True, APID=880, sequence_flags=3, packet_sequence_count_or_name=10705, data_length=265),
#  Container(ccsds_version=0, packet_type=0, secondary_header_flag=True, APID=1138, sequence_flags=3, packet_sequence_count_or_name=1881, data_length=265),
#  Container(ccsds_version=0, packet_type=0, secondary_header_flag=True, APID=1138, sequence_flags=3, packet_sequence_count_or_name=1882, data_length=265)]

# %%
collections.Counter([h.ccsds_version for h in packet_headers])
# Out:
# Counter({0: 2184})

# %%
collections.Counter([h.packet_type for h in packet_headers])
# Out:
# Counter({0: 2184})

# %%
collections.Counter([h.secondary_header_flag for h in packet_headers])
# Out:
# Counter({True: 1816, False: 368})

# %%
collections.Counter([h.APID for h in packet_headers])
# Out:
# Counter({1393: 134,
#          624: 134,
#          880: 133,
#          1138: 55,
#          1140: 803,
#          2047: 368,
#          0: 35,
#          1139: 203,
#          1137: 319})

# %%
apids = {h.APID for h in packet_headers}
{apid: collections.Counter([
    h.secondary_header_flag
    for h in packet_headers if h.APID == apid]) for apid in apids}
# Out:
# {0: Counter({True: 35}),
#  624: Counter({True: 134}),
#  1393: Counter({True: 134}),
#  1138: Counter({True: 55}),
#  880: Counter({True: 133}),
#  1140: Counter({True: 803}),
#  1139: Counter({True: 203}),
#  1137: Counter({True: 319}),
#  2047: Counter({False: 368})}

# %%
collections.Counter([h.sequence_flags for h in packet_headers])
# Out:
# Counter({3: 2184})

# %%
collections.Counter([h.data_length for h in packet_headers])
# Out:
# Counter({265: 2184})

# %%
space_packets = [f[6+15+k*packet_len:][:packet_len]
                 for f in frames[vcid == 7] for k in range(4)]
by_apid = {apid: [] for apid in apids}
for packet, header in zip(space_packets, packet_headers):
    by_apid[header.APID].append(packet)
by_apid = {apid: np.array(by_apid[apid]) for apid in apids}

# %%
#for apid in apids:
#    data = by_apid[apid]
#    plt.figure(figsize=(8, 8 * data.shape[0] / 100))
#    plt.imshow(data, interpolation='none', aspect='auto')
#    plt.title(f'STEREO-A space weather beacon APID {apid}')
import numpy as np
import matplotlib.pyplot as plt

def write_binary_file(data_array, file_path):
    # Convert the array to bytes
    data_bytes = data_array.tobytes()

    # Write the bytes to a file
    with open(file_path, 'wb') as file:
        file.write(data_bytes)

def write_apids_to_files(apids, by_apid):
    for apid in apids:
        data = by_apid[apid]

        # Generate a unique file name for each APID
        file_path = f'output_{apid}.bin'

        # Write the data to a binary file
        write_binary_file(data, file_path)

        # Plotting code (optional)
        plt.figure(figsize=(8, 8 * data.shape[0] / 100))
        plt.imshow(data, interpolation='none', aspect='auto')
        plt.title(f'STEREO-A space weather beacon APID {apid}')
        plt.show()

write_apids_to_files(apids, by_apid)

# %%
non_idle = [h.APID != 2047 for h in packet_headers]
packet_timestamps_secs = np.array(space_packets)[non_idle, 6:10].view('uint32').byteswap().ravel()

# %%
datetime.datetime(2022, 9, 24, 10, 35, 0) - datetime.timedelta(seconds=int(packet_timestamps_secs[0]))
# Out:
# datetime.datetime(1957, 3, 24, 13, 6, 31)

# %%
ccsds_epoch = np.datetime64('1958-01-01T00:00:00')
packet_timestamps = ccsds_epoch + np.timedelta64(1, 's') * packet_timestamps_secs
packet_timestamps[0]
# Out:
# numpy.datetime64('2023-07-03T21:28:29')

# %%
apids_for_timestamps = np.array([h.APID for h in packet_headers if h.APID != 2047])
tmtimestaps_for_timestamps = np.repeat(timestamps[vcid == 7], 4)[non_idle]

# %%
for apid in apids:
    sel = apids_for_timestamps == apid
    plt.plot(tmtimestaps_for_timestamps[sel], packet_timestamps[sel], '.-',
             label=f'APID {apid}')
plt.legend()
plt.title('Space Packet timestamps versus TM frame timestamps')
plt.xlabel('TM frame timestamp')
plt.ylabel('Space Packet timestamp');

# %%
plt.imshow(np.array(space_packets)[non_idle, 6:6+16], aspect='auto', interpolation='none');

# %%
plt.imshow(np.array(space_packets)[:, 6:6+16], aspect='auto', interpolation='none');

# %% [markdown]
# ## S/WAVES beacon data

# %%
swaves_data = by_apid[1393][:, 29:29+159]
swaves_timestamps = packet_timestamps[apids_for_timestamps == 1393]

plt.imshow(swaves_data.T[::-1], aspect='auto', interpolation='none',
           extent=[mdates.date2num(swaves_timestamps[0]),
                   mdates.date2num(swaves_timestamps[-1]),
                   0.125, 16.025,])
plt.gca().xaxis_date()
plt.colorbar()
plt.title('STEREO-A space weather beacon: S/WAVES instrument (APID 1393)\nVia the Mighty Little Dish (66cm) at VE7TIL')
plt.xlabel('Space Packet timestamp')
plt.ylabel('Frequency (MHz)');

# %%
swaves_timestamps
# Out:
# array(['2023-07-03T21:28:29', '2023-07-03T21:29:29',
#        '2023-07-03T21:30:29', '2023-07-03T21:31:29',
#        '2023-07-03T21:32:29', '2023-07-03T21:33:29',
#        '2023-07-03T21:34:29', '2023-07-03T21:35:29',
#        '2023-07-03T21:36:29', '2023-07-03T21:37:29',
#        '2023-07-03T21:38:29', '2023-07-03T21:39:29',
#        '2023-07-03T21:40:29', '2023-07-03T21:41:29',
#        '2023-07-03T21:42:29', '2023-07-03T21:43:29',
#        '2023-07-03T21:44:29', '2023-07-03T21:46:29',
#        '2023-07-03T21:47:29', '2023-07-03T21:48:29',
#        '2023-07-03T21:49:29', '2023-07-03T21:50:29',
#        '2023-07-03T21:51:29', '2023-07-03T21:52:29',
#        '2023-07-03T21:53:29', '2023-07-03T21:54:29',
#        '2023-07-03T21:55:29', '2023-07-03T21:56:29',
#        '2023-07-03T21:57:29', '2023-07-03T21:58:29',
#        '2023-07-03T21:59:29', '2023-07-03T22:00:29',
#        '2023-07-03T22:01:29', '2023-07-03T22:02:29',
#        '2023-07-03T22:03:29', '2023-07-03T22:04:29',
#        '2023-07-03T22:05:29', '2023-07-03T22:06:29',
#        '2023-07-03T22:07:29', '2023-07-03T22:08:29',
#        '2023-07-03T22:09:29', '2023-07-03T22:10:29',
#        '2023-07-03T22:11:29', '2023-07-03T22:12:29',
#        '2023-07-03T22:13:29', '2023-07-03T22:14:29',
#        '2023-07-03T22:15:29', '2023-07-03T22:16:29',
#        '2023-07-03T22:17:29', '2023-07-03T22:18:29',
#        '2023-07-03T22:19:29', '2023-07-03T22:20:29',
#        '2023-07-03T22:21:29', '2023-07-03T22:22:29',
#        '2023-07-03T22:23:29', '2023-07-03T22:24:29',
#        '2023-07-03T22:25:29', '2023-07-03T22:26:29',
#        '2023-07-03T22:27:29', '2023-07-03T22:28:29',
#        '2023-07-03T22:29:29', '2023-07-03T22:30:29',
#        '2023-07-03T22:32:29', '2023-07-03T22:33:29',
#        '2023-07-03T22:34:29', '2023-07-03T22:35:29',
#        '2023-07-03T22:36:29', '2023-07-03T22:37:29',
#        '2023-07-03T22:38:29', '2023-07-03T22:39:29',
#        '2023-07-03T22:40:29', '2023-07-03T22:41:29',
#        '2023-07-03T22:42:29', '2023-07-03T22:43:29',
#        '2023-07-03T22:44:29', '2023-07-03T22:45:29',
#        '2023-07-03T22:46:29', '2023-07-03T22:47:29',
#        '2023-07-03T22:48:29', '2023-07-03T22:49:29',
#        '2023-07-03T22:50:29', '2023-07-03T22:51:29',
#        '2023-07-03T22:52:29', '2023-07-03T22:53:29',
#        '2023-07-03T22:54:29', '2023-07-03T22:55:29',
#        '2023-07-03T22:56:29', '2023-07-03T22:57:29',
#        '2023-07-03T22:58:29', '2023-07-03T22:59:29',
#        '2023-07-03T23:00:29', '2023-07-03T23:01:29',
#        '2023-07-03T23:02:29', '2023-07-03T23:03:29',
#        '2023-07-03T23:04:29', '2023-07-03T23:05:29',
#        '2023-07-03T23:06:29', '2023-07-03T23:07:29',
#        '2023-07-03T23:08:29', '2023-07-03T23:09:29',
#        '2023-07-03T23:10:29', '2023-07-03T23:11:29',
#        '2023-07-03T23:12:29', '2023-07-03T23:13:29',
#        '2023-07-03T23:14:29', '2023-07-03T23:15:29',
#        '2023-07-03T23:16:29', '2023-07-03T23:17:29',
#        '2023-07-03T23:18:29', '2023-07-03T23:19:29',
#        '2023-07-03T23:20:29', '2023-07-03T23:21:29',
#        '2023-07-03T23:22:29', '2023-07-03T23:23:29',
#        '2023-07-03T23:24:29', '2023-07-03T23:25:29',
#        '2023-07-03T23:26:29', '2023-07-03T23:27:29',
#        '2023-07-03T23:28:29', '2023-07-03T23:29:29',
#        '2023-07-03T23:30:29', '2023-07-03T23:31:29',
#        '2023-07-03T23:32:29', '2023-07-03T23:33:29',
#        '2023-07-03T23:34:29', '2023-07-03T23:35:29',
#        '2023-07-03T23:36:29', '2023-07-03T23:37:29',
#        '2023-07-03T23:38:29', '2023-07-03T23:39:29',
#        '2023-07-03T23:40:29', '2023-07-03T23:41:29',
#        '2023-07-03T23:42:29', '2023-07-03T23:43:29'],
#       dtype='datetime64[s]')

# %%
plt.plot(by_apid[1393][:, 26:29]);

# %%
plt.plot(swaves_timestamps, by_apid[1393][:, 10:12].copy().view('uint16').byteswap(), '.-')
plt.title('STEREO-A APID 1393 bytes 10 & 11 (uint16)')
plt.ylabel('Value')
plt.xlabel('Space Packet timestamp')
# Out:
# Text(0.5, 0, 'Space Packet timestamp')
